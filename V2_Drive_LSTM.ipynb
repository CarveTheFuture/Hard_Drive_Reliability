# %% [markdown]
# <a href="https://colab.research.google.com/github/CarveTheFuture/Hard_Drive_Reliability/blob/main/V2_Drive_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pytorch
# Out:
# ...
#   ERROR: Failed building wheel for pytorch
#   Running setup.py clean for pytorch
# Failed to build pytorch
# ...
#     Running setup.py install for pytorch ... error
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-udmf392c/pytorch/setup.py'"'"'; __file__='"'"'/tmp/pip-install-udmf392c/pytorch/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-8q_5fz1g/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.

# %%
import torch
import torch.nn as nn

import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import csv, sqlite3
import matplotlib.pyplot as plt
import numpy as np

# %%
query1='''SELECT serial_number  FROM q1_2019 WHERE failure IN (1) AND model='ST4000DM000';'''

# %%
result = None
try:
    con = sqlite3.connect("/content/drive/MyDrive/Analysis_Deta/2019/2019_drive.db") # change to 'sqlite:///your_filename.db'
    cur = con.cursor()
    #df = pd.read_csv(csv_file)
    #df.to_sql('q2_2019', con, if_exists='append', index=False)
    ##cur.executemany("INSERT INTO t (col1, col2) VALUES (?, ?);", to_db)
    #cur.execute(query)
    cur.execute(query4)
    result = cur.fetchall()
    con.commit()
    con.close()
except sqlite3.Error as error:
    print(f"Error: '{error}'" )
finally:
    if (con):
        con.close()
        print("The SQLite connection is closed")
# Out:
# The SQLite connection is closed

# %%
serial4=pd.DataFrame(result)

# %%
serial4
# Out:
#             0
# 0    Z304KX6Y
# 1    Z303YVGQ
# 2    Z304K4BB
# 3    Z304L9AM
# 4    Z302723D
# ..        ...
# 114  Z302SZP3
# 115  Z302T7TL
# 116  Z305D2ZG
# 117  S301K5QN
# 118  S301GMEP
#
# [119 rows x 1 columns]

# %%
serial_f=serial_f.append(serial4)

# %%
serial_f
# Out:
#             0
# 0    S300YTAY
# 1    S300ZREZ
# 2    Z302T6AB
# 3    Z3026Q5Y
# 4    W300THEG
# ..        ...
# 114  Z302SZP3
# 115  Z302T7TL
# 116  Z305D2ZG
# 117  S301K5QN
# 118  S301GMEP
#
# [402 rows x 1 columns]

# %%
serial_names=serial_f.values

# %%
query4='''SELECT *  FROM q4_2019 WHERE serial_number IN ('S300YTAY','S300ZREZ','Z302T6AB','Z3026Q5Y','W300THEG','Z3040Z4M','Z304JMZP','Z304ZBFY','S301GM8H','S301GPB1','S301GS1L','Z303XYPJ','Z302T7JZ','S301GQA4','Z303Y470','S300Z60X','Z3059CCB','Z302F0C0','Z3025LXD','Z304JWPG','Z300PQPQ','Z302F2WA','S301NKQV','Z302T6A8','Z304HSVA','Z3025M1G','S300TS9Z','Z302SYPR','Z3041TE5','Z304JJ0A','Z304L8JW','Z304JN7J','Z303MZ9Y','Z30251XR','Z3025LRK','Z300YLXG','S300X3XJ','Z302SR45','S300Z5S4','Z304JM43','S300WCSR','Z304L856','Z305DXS7','Z300VXA5','Z302CYHA','Z302EQBN','Z304JG10','Z305PV18','Z302T6F4','S300Z4LV','Z305DHXM','Z304LAEN','S300XE94','S30115HR','Z3025K5H','S301PSAT','Z304HV83','Z304HTKM','S300XCAB','Z30251BE','Z302T6J5','Z3029AR3','S301GM66','S300ZQVL','Z30513PV','Z305D56S','S300Z43B','Z3039XWR','S3010LCN','Z304J0NT','S301NH5Z','Z30251SR','Z302T6CW','Z305DVWM','Z305DF66','Z305NZY4','S300Z8CZ','S301GP8P','Z304HSCX','Z305BE77','Z30271N2','Z304LK31','S300XB04','S301PS84','Z304JNC9','Z304JHF7','Z302EPJK','Z305758R','Z304JDDH','S300ZRP2','Z3041J67','S301NXNV','Z304RKYC','Z305BFRR','Z3041NJE','Z302SZJZ','Z304HRM4','Z302T88V','Z302SRFQ','Z3053NZ4','S300YC5D','S301GQQV','Z304KCJZ','S300Z7G1','Z302SZLQ','S301NGZN','S301GNWY','Z304JSVS','Z304TDET','Z305D68P','Z305GWDQ','Z305D5L0','Z304KCPF','Z304KR0Q','S300WGHB','Z3054R08','S300Z4YH','S301GQV4','Z303N1QB','Z304HM08','Z304YF91','Z304LA21','S300XAP9','Z304JMK8','Z304JVYJ','Z3052BGS','Z305GV90','Z3027HSX','Z305DH9R','Z304TK95','Z302T88T','S301KX89','Z304HTM1','Z3029GTD','Z3029ZS5','Z302FZH2','Z302SQTF','Z304HPX7','Z304JD9J','S301GR6X','Z302T7P7','Z302SYJA','S301NKJR','S301NH71','Z304J0TR','Z305C0ZN','S30108L3','Z302AKLA','Z302T88H','S300Z8P7','Z305D34Z','Z305GXC1','Z3058XP6','S301GNF9','Z302SYHF','Z304JMA0','S301PCJF','Z3051DGR','Z305D4L5','Z30468K9','Z305D6G2','S300Z6HR','Z304WT4G','Z304JDL5','Z304KR1N','S301K6XV','Z304LDL0','Z304JT1B','Z305A432','S3011818','Z302T6BL','Z305B5X2','Z304176Y','S301GRVB','S301GRL1','Z304KCYE','Z303QAX3','S301168X','Z305D51Q','Z305KVHS','S301GQX5','Z304V9Z7','Z304JDL3','Z302SZJH','Z304KBQR','S300WD1K','Z305BYTD','Z304JWQ9','Z302T6JA','Z304JP0J','Z304JVZY','Z304TJRT','S30115TG','S300Z6M5','Z304JW84','Z305DHV4','S301GNMZ','Z302ALD9','S300Z731','Z304GWHB','S300Z5JP','Z302SLDV','S301GND9','Z302701J','Z302T6JR','Z304JWPZ','Z305CXS7','S301GRGY','Z30417KE','Z305D2NT','Z302G15C','S301GVK8','Z305B6L0','Z304LA3D','S300Z4HB','S300VLA2','S300YSEP','S301GNX4','S301GQ54','Z302AB82','Z304JW4P','Z304JG8D','S301GMBN','S301NK5Y','Z305D21E','Z304L9TZ','Z302AL1L','Z3059JXC','Z304HWJF','Z305D66M','S301GMK4','S301K0WJ','S301PQ1F','Z302SYMP','Z302T7HK','S300Z5G1','Z304JKG7','Z302T8LB','Z30429G2','Z304KD5E','Z304KCFR','S301GLWT','S301KWTE','S301GQZD','Z302SQJ9','S301167F','S301K0GV','Z304HSX5','Z304NLHM','Z305L695','Z305KWFK','Z304J2H9','Z3025HSR','Z305K2J0','Z304GWJA','Z303R1DE','Z304NGFR','Z305DVQ7','S301NL7L','Z3029GKK','S301K0XF','S301GQVW','Z302SZ70','Z302SW4B','Z303LQN7','S301GNWB','Z302SXL0','Z3059KNJ','Z304KABR','Z302SZ0A','Z302T7ST','S301P0ES','S301GQ7K','Z304DWCH','Z304ZN6J','Z304T5E0','Z304HZ89','Z302SZ6R','Z304JNLW','S301M4YT','Z302F381','Z304JVY9','Z302S7HN','Z304KX6Y','Z303YVGQ','Z304K4BB','Z304L9AM','Z302723D','Z304JZG7','Z304HV08','S300YPK7','Z304JPTZ','Z304JGSZ','Z305CJQC','Z305LRK9','S301GQJG','Z304J0QA','Z304JJ7R','S301GQSM','Z305D4XN','Z304JLCE','S301GMCV','S300WDA3','S300YSGX','S301GMM5','S301GVLL','Z304JPN3','W301AY5V','Z302SWXD','Z3029FAN','Z305D6QR','S3010M10','Z304HK9B','S301LN54','S300Z43Q','Z304KCQR','S301F73K','S301GMR1','Z302B0NP','Z304L9AJ','Z304X7VV','Z304JZH6','Z303RRM9','Z304HKAG','Z304JPSZ','S301K7KZ','Z304QHY7','Z3040DVF','S300Z7AD','Z304KCR9','Z304HGW3','Z302SX25','Z304JS04','Z302SZ1N','S300Z9A6','S30115AC','Z304JP7M','Z302T6AQ','Z304JLPT','Z304HSCT','Z302BV7C','Z30555PB','S301GP34','S301GT3N','Z304JM7Q','Z304VW9S','Z3050DVF','Z304HP4Z','Z302T9AH','Z302T8WF','Z304HSN8','Z304JLZW','Z302T7X4','Z305D6RP','Z302T68R','Z304H823','Z302T88S','S301P6Y6','Z304TPPK','Z304JGD1','S30108RC','Z304JG8K','Z305CTEC','Z304Y4NZ','Z30544RS','Z3040DW9','Z305KW12','S301P21G','S301GQG3','Z304LA61','Z304KCCF','Z302712G','Z302SZHM','S3010D9D','Z305AXS8','Z305D4WT','Z304JPNA','S301GP0D','Z302T6LE','S301PSFV','Z305D2MG','Z305GXJW','Z304JZK4','Z305GW1E','Z305D489','Z304KBKG','Z304V9DH','Z303XYBR','S301GTX8','Z3041NA6','Z304RLGF','Z304HVC0','Z303QPVA','Z302SXK7','Z304HS1X','Z304XN5C','Z305DW3N','Z302SZP3','Z302T7TL','Z305D2ZG','S301K5QN','S301GMEP');'''

# %%
data4=pd.DataFrame(result)

# %%
data4
# Out:
#              0         1            2              3    ...   127   128   129   130
# 0     2019-10-01  Z302BV7C  ST4000DM000  4000787030016  ...  None  None  None  None
# 1     2019-10-01  Z305DW3N  ST4000DM000  4000787030016  ...  None  None  None  None
# 2     2019-10-01  Z304JPSZ  ST4000DM000  4000787030016  ...  None  None  None  None
# 3     2019-10-01  Z302B0NP  ST4000DM000  4000787030016  ...  None  None  None  None
# 4     2019-10-01  Z304JLPT  ST4000DM000  4000787030016  ...  None  None  None  None
# ...          ...       ...          ...            ...  ...   ...   ...   ...   ...
# 5132  2019-12-19  S301GMEP  ST4000DM000  4000787030016  ...  None  None  None  None
# 5133  2019-12-20  S301K5QN  ST4000DM000  4000787030016  ...  None  None  None  None
# 5134  2019-12-20  S301GMEP  ST4000DM000  4000787030016  ...  None  None  None  None
# 5135  2019-12-21  S301K5QN  ST4000DM000  4000787030016  ...  None  None  None  None
# ...

# %%
data=data.append(data4)

# %%
#4
cols='date,serial_number,model,capacity_bytes,failure,smart_1_normalized,smart_1_raw,smart_2_normalized,smart_2_raw,smart_3_normalized,smart_3_raw,smart_4_normalized,smart_4_raw,smart_5_normalized,smart_5_raw,smart_7_normalized,smart_7_raw,smart_8_normalized,smart_8_raw,smart_9_normalized,smart_9_raw,smart_10_normalized,smart_10_raw,smart_11_normalized,smart_11_raw,smart_12_normalized,smart_12_raw,smart_13_normalized,smart_13_raw,smart_15_normalized,smart_15_raw,smart_16_normalized,smart_16_raw,smart_17_normalized,smart_17_raw,smart_18_normalized,smart_18_raw,smart_22_normalized,smart_22_raw,smart_23_normalized,smart_23_raw,smart_24_normalized,smart_24_raw,smart_168_normalized,smart_168_raw,smart_170_normalized,smart_170_raw,smart_173_normalized,smart_173_raw,smart_174_normalized,smart_174_raw,smart_177_normalized,smart_177_raw,smart_179_normalized,smart_179_raw,smart_181_normalized,smart_181_raw,smart_182_normalized,smart_182_raw,smart_183_normalized,smart_183_raw,smart_184_normalized,smart_184_raw,smart_187_normalized,smart_187_raw,smart_188_normalized,smart_188_raw,smart_189_normalized,smart_189_raw,smart_190_normalized,smart_190_raw,smart_191_normalized,smart_191_raw,smart_192_normalized,smart_192_raw,smart_193_normalized,smart_193_raw,smart_194_normalized,smart_194_raw,smart_195_normalized,smart_195_raw,smart_196_normalized,smart_196_raw,smart_197_normalized,smart_197_raw,smart_198_normalized,smart_198_raw,smart_199_normalized,smart_199_raw,smart_200_normalized,smart_200_raw,smart_201_normalized,smart_201_raw,smart_218_normalized,smart_218_raw,smart_220_normalized,smart_220_raw,smart_222_normalized,smart_222_raw,smart_223_normalized,smart_223_raw,smart_224_normalized,smart_224_raw,smart_225_normalized,smart_225_raw,smart_226_normalized,smart_226_raw,smart_231_normalized,smart_231_raw,smart_232_normalized,smart_232_raw,smart_233_normalized,smart_233_raw,smart_235_normalized,smart_235_raw,smart_240_normalized,smart_240_raw,smart_241_normalized,smart_241_raw,smart_242_normalized,smart_242_raw,smart_250_normalized,smart_250_raw,smart_251_normalized,smart_251_raw,smart_252_normalized,smart_252_raw,smart_254_normalized,smart_254_raw,smart_255_normalized,smart_255_raw'

# %%
#5
col_names=cols.split (",")

# %%
len(col_names)
# Out:
# 131

# %%
#6
data.columns=col_names
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-4c98e5866aa7> in <module>()
#       1 #6
# ----> 2 data.columns=col_names
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5152         try:
#    5153             object.__getattribute__(self, name)
# -> 5154             return object.__setattr__(self, name, value)
#    5155         except AttributeError:
#    5156             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# ...

# %%
#4
fail_indices=data[data['failure'].isin([1])]
fail_indices
# Out:
#        Unnamed: 0  ...                                       fail_date
# 258           258  ...    258    2019-01-01\nName: date, dtype: object
# 270           270  ...    270    2019-01-01\nName: date, dtype: object
# 684           684  ...    684    2019-01-02\nName: date, dtype: object
# 703           703  ...    703    2019-01-02\nName: date, dtype: object
# 812           812  ...    812    2019-01-03\nName: date, dtype: object
# ...           ...  ...                                             ...
# 95574        5126  ...  24748    2019-03-10\nName: date, dtype: object
# 95577        5129  ...   5062    2019-12-12\nName: date, dtype: object
# 95579        5131  ...   1685    2019-07-09\nName: date, dtype: object
# 95583        5135  ...  20319    2019-02-24\nName: date, dtype: object
# 95584        5136  ...   5136    2019-01-13\nName: date, dtype: object
#
# [506 rows x 133 columns]

# %%
#5
fail_sort=fail_indices.sort_values('smart_9_raw', axis=0, ascending=True, inplace=False)

# %%
#6
fail_sort=fail_sort.reset_index(drop=True)

# %%
fail_sort['smart_9_raw'][502:]
# Out:
# 502    41327.0
# 503    41466.0
# 504    42189.0
# Name: smart_9_raw, dtype: float64

# %%
data.head(3)
# Out:
#    Unnamed: 0  ...                                          fail_date
# 0           0  ...      4011    2019-11-13\nName: date, dtype: object
# 1           1  ...     10102    2019-01-27\nName: date, dtype: object
# 2           2  ...  21682    2019-06-28\n21682    2019-06-28\nName...
#
# [3 rows x 133 columns]

# %%
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#7
fail_sort['perform'] = pd.Series([1 for x in range(len(fail_sort.index))])
fail_sort['perform'][2:5] = pd.Series([2 for x in range(3)])
fail_sort['perform'][5:7] = pd.Series([3 for x in range(2)])
fail_sort['perform'][7:9] = pd.Series([4 for x in range(2)])
fail_sort['perform'][9:13] = pd.Series([5 for x in range(4)])
fail_sort['perform'][13:72] = pd.Series([6 for x in range(72-13)])
fail_sort['perform'][72:192] = pd.Series([7 for x in range(192-72)])
fail_sort['perform'][192:317] = pd.Series([8 for x in range(317-192)])
fail_sort['perform'][317:397] = pd.Series([9 for x in range(397-317)])
fail_sort['perform'][397:487] = pd.Series([10 for x in range(487-397)])
fail_sort['perform'][487:502] = pd.Series([11 for x in range(502-487)])
fail_sort['perform'][502:505] = pd.Series([12 for x in range(505-502)])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
len(fail_sort)
# Out:
# 505

# %%
def get_fail_date(in_serial):
  

  return fail_indices[(fail_indices['serial_number']==in_serial)]['date'][0]

# %%
#8
mid=fail_sort[['date','serial_number','perform']]

# %%
#9
data=data.join(mid.set_index('serial_number'), on='serial_number',rsuffix='_fail')

# %%
get_fail_date('S301K5QN')
# Out:
# Timestamp('2019-12-21 00:00:00')

# %%
(get_fail_date('S301K5QN')-get_fail_date('S301GMEP'))/np.timedelta64(1, 'D')
# Out:
# date
# 2019-12-21    0.0
# Name: date, dtype: float64

# %%
len(data)
# Out:
# 95580

# %%
#10
for i in col_names:
  try:
    if math.isnan(data[i].std()):
      data=data.drop(i,axis=1)
      print(data[i])
  except:
    pass

# %%
#11
for i in col_names:
  try:
    if data[i].std()==0:
      data=data.drop(i,axis=1)
      print(data[i])
  except:
    pass

# %%
#12
for i in col_names:
  try:
    if data[i].count()==0:
      data=data.drop(i,axis=1)
      print(data[i])
  except:
    pass

# %%
data=data.drop('fail_date',axis=1)

# %%
data.to_csv('/content/drive/MyDrive/Analysis_Deta/2019/2019_drive_Failures')

# %%
data.to_csv('/content/drive/MyDrive/Analysis_Deta/2019/2019_drive_Failure_processed')

# %%
#3
data=pd.read_csv('/content/drive/MyDrive/Analysis_Deta/2019/2019_drive_Failures')

# %%
data.head()
# Out:
#    Unnamed: 0        date  ...   date_fail perform
# 0           0  2019-01-01  ...  2019-11-13      11
# 1           1  2019-01-01  ...  2019-01-27       7
# 2           2  2019-01-01  ...  2019-06-28       7
# 2           2  2019-01-01  ...  2019-06-28       7
# 3           3  2019-01-01  ...  2019-06-10       8
#
# [5 rows x 44 columns]

# %%
to_drop=[]
for i in col_names:
  try:
    index = data['smart_1_normalized'].index[data['smart_1_normalized'].apply(np.isnan)]
    to_drop.append(index)
  except:
    pass

# %%
#10
index = data['perform'].index[data['perform'].apply(np.isnan)]
len(index)
index
# Out:
# Int64Index([], dtype='int64')

# %%
np.where(np.isnan(data['perform'].values))

# %%
data.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4b3bc28f6b01> in <module>()
# ----> 1 data.reset_index(drop=True)
#
# NameError: name 'data' is not defined

# %%
data.plot(x='date',y='smart_9_raw',figsize=(12,8))

# %%
# import labelencoder
from sklearn.preprocessing import LabelEncoder
# instantiate labelencoder object
le = LabelEncoder()
#Apply LabelEncoder on each of the categorical columns:
data['serial'] = le.fit_transform(data['serial_number'])

# %%
X_train=data.iloc[0:95254]
X_test=data.iloc[95254:]

# %%
X_test=data.iloc[0:95254
X_test=data.iloc[0:95254

# %%
def get_date(fail_date):
  return fail_date.split('    ')[1][0:10]

# %%
b=X_test['fail_date'].transform(get_date)

# %%
X_train['fail_date']=pd.to_datetime(a, yearfirst=True)
X_test['fail_date']=pd.to_datetime(b, yearfirst=True)

# %%
data['fail_date']=pd.to_datetime(data['fail_date'], yearfirst=True)
data['date']=pd.to_datetime(data['date'], yearfirst=True)
data['life_left']=(data['fail_date']-data['date'])/ np.timedelta64(1,'D')

# %%
X_train['date']=pd.to_datetime(X_train['date'], yearfirst=True)
X_test['date']=pd.to_datetime(X_test['date'], yearfirst=True)

# %%
X_train['life_left']=X_train['fail_date']-X_train['date']

# %%
X_train.to_csv('/content/drive/MyDrive/Analysis_Deta/2019/Model_Inputs/X_train_hours.csv')

# %%
X_test.to_csv('/content/drive/MyDrive/Analysis_Deta/2019/Model_Inputs/X_test_hours.csv')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Fit on training set only.
scaler.fit(X_train)

# Apply transform to both the training set and the test set.
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.min(axis=1)
# Out:
# array([-0.67074476, -0.68348233, -1.77334816, ..., -1.09536784,
#        -1.34604827, -2.50780277])

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(.95)

# %%
pca.fit(X_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=0.95, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
data.isnull().any()
# Out:
# Unnamed: 0              False
# date                    False
# serial_number           False
# model                   False
# failure                 False
# smart_1_normalized      False
# smart_1_raw             False
# smart_3_normalized      False
# smart_4_raw             False
# smart_5_normalized      False
# smart_5_raw             False
# smart_7_normalized      False
# smart_7_raw             False
# smart_9_normalized      False
# smart_9_raw             False
# smart_12_raw            False
# smart_183_normalized    False
# smart_183_raw           False
# smart_184_normalized    False
# smart_184_raw           False
# smart_187_normalized    False
# smart_187_raw           False
# smart_188_raw           False
# smart_189_normalized    False
# smart_189_raw           False
# smart_190_normalized    False
# smart_190_raw           False
# smart_192_raw           False
# smart_193_normalized    False
# smart_193_raw           False
# smart_194_normalized    False
# ...

# %%
fail_sort.isnull().any()
# Out:
# Unnamed: 0              False
# date                    False
# serial_number           False
# model                   False
# failure                 False
# smart_1_normalized      False
# smart_1_raw             False
# smart_3_normalized      False
# smart_4_raw             False
# smart_5_normalized      False
# smart_5_raw             False
# smart_7_normalized      False
# smart_7_raw             False
# smart_9_normalized      False
# smart_9_raw             False
# smart_12_raw            False
# smart_183_normalized    False
# smart_183_raw           False
# smart_184_normalized    False
# smart_184_raw           False
# smart_187_normalized    False
# smart_187_raw           False
# smart_188_raw           False
# smart_189_normalized    False
# smart_189_raw           False
# smart_190_normalized    False
# smart_190_raw           False
# smart_192_raw           False
# smart_193_normalized    False
# smart_193_raw           False
# smart_194_normalized    False
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0       failure  ...  smart_255_normalized  smart_255_raw
# count  95580.000000  95580.000000  ...                   0.0            0.0
# mean   11602.362754      0.005284  ...                   NaN            NaN
# std     7894.702182      0.072496  ...                   NaN            NaN
# min        0.000000      0.000000  ...                   NaN            NaN
# 25%     4779.000000      0.000000  ...                   NaN            NaN
# 50%    10663.000000      0.000000  ...                   NaN            NaN
# 75%    17376.000000      0.000000  ...                   NaN            NaN
# max    31511.000000      1.000000  ...                   NaN            NaN
#
# [8 rows x 115 columns]

# %%
pca.n_components_
# Out:
# 2
